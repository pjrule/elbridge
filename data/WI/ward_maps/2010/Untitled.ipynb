# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
wi = gpd.read_file('2002_2010_Election_Data_with_2017_Wards.shp')
wi.plot()

# %%
wi[wi.GEOID=='55003425620001'].plot()

# %%
wi[wi.GEOID=='55029836000001'].plot()

# %%
wi.geometry.scale(2, 1).plot()
plt.show()

# %%
type(wi.geometry)
# Out:
# geopandas.geoseries.GeoSeries
