# %%
import geopandas as gpd
import matplotlib.pyplot as plt
gdf = gpd.read_file('../data/WI/ward_maps/2010/2002_2010_Election_Data_with_2017_Wards.shp')
gdf.plot()
plt.show()

# %%
aea = gdf.to_crs({'init': 'esri:102003'})
aea.plot()
plt.show()
