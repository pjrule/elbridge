# %%
import pickle
import numpy as np
from sklearn.decomposition import IncrementalPCA

wi = pickle.load(open('wi_data/wi_160.pkl', 'rb'))
wi.load_density_mapping(density_mapping='wi_data/wi_density_160.npy')
# Out:
# /Users/pjrule/anaconda3/lib/python3.6/site-packages/pysal/__init__.py:65: VisibleDeprecationWarning: PySAL's API will be changed on 2018-12-31. The last release made with this API is version 1.14.4. A preview of the next API version is provided in the `pysal` 2.0 prelease candidate. The API changes and a guide on how to change imports is provided at https://pysal.org/about
#   ), VisibleDeprecationWarning)

# %%
wi.reset()
wi.geo_resolution = 65536
wi.load_geo_mapping(geo_mapping='wi_geo_65536.npy.npz') 
wi.geo_weights = wi.geo_weights.T

# %%
wi.geo_weights.shape
# Out:
# (65720, 6924)

# %%
import numpy as np
districts = np.zeros(len(wi.df))
districts[:4000] = 1
districts[4000:] = 16

# %%
import matplotlib.pyplot as plt
orig = np.flipud(wi.geo_weights.dot(districts).reshape(wi.geo_n_rows, wi.geo_n_cols))
orig.tostring()
# Out:
# b'
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-00de4d707d34> in <module>()
#      47                  validation_data=[x_val, y_val], callbacks=early_stopper(params['epochs'], mode='strict'))
#      48
# ---> 49 h = ta.Scan(frames, frames, params=p, model=ae_model, dataset_name='wi_frames', experiment_no=1, grid_sample=0.01)
#
# NameError: name 'frames' is not defined
